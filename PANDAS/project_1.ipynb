# %% [markdown]
# Student Marks Analysis

# %%
import pandas as pd

# %%
student_database = {
    "NAMES": ["Tulsi", "Ducaar", "Mouli", "Jack", "Hemanth", "Pawan"],
    "Python": [90, 60, 40, 70, 40, 0],
    "C++": [40, 60, 70, 90, 30,90],
    "Maths": [50, 60, None, 60, 38, 0]
}

df = pd.DataFrame(student_database)
print(df)
csvv = df.to_csv("student.csv",index=False)
pd.read_csv("student.csv")
# print()
# print(df.head())
# print()
# print(df.tail())
# print()
# print(df.info())
# print()
# print(df.describe())
# print()
# print(df.shape)
# print()
# print(df.columns)
print()
df["Total"] = df[["Maths", "C++", "Python"]].sum(axis=1)
top = df["Total"].max()
print(df[df["Total"] == top])
mi = df.fillna(0)
print(mi)

dp = df.dropna()
print(dp)
# Out:
#      NAMES  Python  C++  Maths
# 0    Tulsi      90   40   50.0
# 1   Ducaar      60   60   60.0
# 2    Mouli      40   70    NaN
# 3     Jack      70   90   60.0
# 4  Hemanth      40   30   38.0
# 5    Pawan       0   90    0.0
#
#      NAMES  Python  C++  Maths
# 0    Tulsi      90   40   50.0
# 1   Ducaar      60   60   60.0
# 2    Mouli      40   70    0.0
# 3     Jack      70   90   60.0
# 4  Hemanth      40   30   38.0
# 5    Pawan       0   90    0.0
#      NAMES  Python  C++  Maths
# 0    Tulsi      90   40   50.0
# 1   Ducaar      60   60   60.0
# 3     Jack      70   90   60.0
# 4  Hemanth      40   30   38.0
# 5    Pawan       0   90    0.0
