# %% [markdown]
# Weather Data Report

# %%
import pandas as pd
import numpy as np

# %%
weather_data = {
    "Days" : pd.date_range(start="1-01-2006",periods=10,freq="D"),
    "Temperature": [32, 35, np.nan, 30, 29, 36, 34, np.nan, 33, 31],
    "Rainfall": [5, 12, 0, 18, 7, 25, 3, 0, 15, 8]
    
}
df = pd.DataFrame(weather_data)

# print("------ Weather Data Report ------")
# print(df.to_string(index=False))

# print("------HOTTEST DAY--------")
# hott = df.loc[df['Temperature'].idxmax()]
# print(hott)

# cold = df.loc[df["Temperature"].idxmin()]
# print(cold)
# print("---MOST RAINFULL DAY---")
# rai = df[df["Rainfall"]>10]
# print(rai)
avgg = df['Temperature'].mean(skipna=True)
print(avgg)
d = df["Temperature"].fillna(avgg,inplace=True)
print(d)
# Out:
# 32.5
# None
# C:\Users\Thula\AppData\Local\Temp\ipykernel_9036\2620463244.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d = df["Temperature"].fillna(avgg,inplace=True)
